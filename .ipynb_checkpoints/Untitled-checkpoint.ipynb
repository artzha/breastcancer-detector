# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cancerData = pd.read_csv('data/data.csv')

# g = sns.FacetGrid(data=cancerData, col='diagnosis')
# g.map(plt.hist, 'radius_mean', bins=50)

s = sns.PairGrid(cancerData[['radius_mean','texture_mean','perimeter_mean', 'diagnosis']], hue='diagnosis')
s.map_upper(sns.regplot) 
s.map_lower(sns.residplot) 
s.map_diag(plt.hist) 
# Takeaways
# More Benign than Malignant data - therefore model accuracy will be more skewed to benign 
# Malignant - mid-size radius, larger perimeter
# Benign - smaller radius, smaller perimeter

# %%
g = sns.PairGrid(cancerData[['smoothness_mean','compactness_mean','area_mean','diagnosis']], hue='diagnosis')
g.map_upper(sns.regplot) 
g.map_lower(sns.residplot) 
g.map_diag(plt.hist) 
# Takeaways
# Malignant - less compact, greater area
# Benign - more compact, smaller area

# %%
g = sns.PairGrid(cancerData[['concavity_mean','concave points_mean','texture_worst','diagnosis']], hue='diagnosis')
g.map_upper(sns.regplot) 
g.map_lower(sns.residplot) 
g.map_diag(plt.hist) 
# Takeaways
# Malignant - greater concavity, greater # of concave_points
# Benign - smaller concavity, less concave_points

# %%
print(cancerData.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#       ...       texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0     ...               17.33           184.60      2019.0            0.1622
# 1     ...               23.41           158.80      1956.0            0.1238
# 2     ...               25.53           152.50      1709.0            0.1444
# 3     ...               26.50            98.87       567.7            0.2098
# 4     ...               16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
g = sns.FacetGrid(data=cancerData, col='diagnosis')
g.map(plt.hist, 'area_mean', bins=50)

# %%
features_mean=list(cancerData.columns[1:11])

# split dataframe into two based on diagnosis
dfM=cancerData[cancerData['diagnosis'] ==1]
dfB=cancerData[cancerData['diagnosis'] ==0]

#Stack the data
plt.rcParams.update({'font.size': 8})
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(8,10))
axes = axes.ravel()
for idx,ax in enumerate(axes):
    ax.figure
    binwidth= (max(cancerData[features_mean[idx]]) - min(cancerData[features_mean[idx]]))/50
    ax.hist([dfM[features_mean[idx]],dfB[features_mean[idx]]], bins=np.arange(min(cancerData[features_mean[idx]]), max(cancerData[features_mean[idx]]) + binwidth, binwidth) , alpha=0.5,stacked=True, normed = True, label=['M','B'],color=['r','g'])
    ax.legend(loc='upper right')
    ax.set_title(features_mean[idx])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-4039dd68ed97> in <module>()
#      11 for idx,ax in enumerate(axes):
#      12     ax.figure
# ---> 13     binwidth= (max(cancerData[features_mean[idx]]) - min(cancerData[features_mean[idx]]))/50
#      14     ax.hist([dfM[features_mean[idx]],dfB[features_mean[idx]]], bins=np.arange(min(cancerData[features_mean[idx]]), max(cancerData[features_mean[idx]]) + binwidth, binwidth) , alpha=0.5,stacked=True, normed = True, label=['M','B'],color=['r','g'])
#      15     ax.legend(loc='upper right')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
features_mean=list(cancerData.columns[1:11])
print(features_mean)
